# %%
import pandas as pd

weather = pd.read_csv('../data/chicago_hourly_weather.csv')
print(weather.info())
print(weather.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        15335 non-null  object
#  1   datetime    15335 non-null  object
#  2   temp        15335 non-null  float64
#  3   feelslike   15335 non-null  float64
#  4   precip      15335 non-null  float64
#  5   preciptype  1654 non-null   object
#  6   snow        15335 non-null  float64
#  7   snowdepth   15335 non-null  float64
#  8   cloudcover  15335 non-null  float64
#  9   visibility  15335 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 1.2+ MB
# None
#           name             datetime  temp  feelslike  precip preciptype  snow  \
# 0  Chicago, IL  2023-01-01T00:00:00  37.1       32.0   0.000        NaN   0.0
# 1  Chicago, IL  2023-01-01T01:00:00  37.6       33.1   0.000        NaN   0.0
# ...

# %%
weather = weather.drop_duplicates(subset=['datetime'], keep='first')
weather.to_csv('../data/chicago_hourly_weather.csv', index=False)
